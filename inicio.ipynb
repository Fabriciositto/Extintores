# %%
import pandas as pd

# %%
planta=pd.read_csv("PLANTA.csv",header=1)
reserva=pd.read_csv("RESERVA.csv",header=1)

# %%
planta.head(20)
# Out:
#       Unnamed: 0  Orden      LOTE RESPONSABLE      EDIFICO  \
# 0            NaN    1.0  LOTE 101         NaN  Chapisteria
# 1            NaN    2.0  LOTE 101         NaN  Chapisteria
# 2            NaN    3.0  LOTE 101         NaN  Chapisteria
# 3            NaN    4.0  LOTE 101         NaN  Chapisteria
# 4            NaN    5.0  LOTE 101         NaN  Chapisteria
# ...          ...    ...       ...         ...          ...
# 1431         NaN    NaN       NaN         NaN          NaN
# 1432         NaN    NaN       NaN         NaN          NaN
# 1433         NaN    NaN       NaN         NaN          NaN
# 1434         NaN    NaN       NaN         NaN          NaN
# 1435         NaN    NaN       NaN         NaN          NaN
#
#                         UBICACIÓN TIPO CLASE   CAP. VTO DE CARGA  ...  \
# 0      Chapa - Sub Estación Chica  CO2    BC  10 Kg      11/2020  ...
# 1      Chapa - Sub Estación Chica  CO2    BC  10 Kg      11/2020  ...
# ...

# %%
reserva.head(20)
